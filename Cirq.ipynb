# %%
pip install cirq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cirq
import numpy as np

# %%
cubit = cirq.NamedQubit("hola")
cubit2 = cirq.NamedQubit("hola")

# %%
cubit == cubit2
# Out:
# True

# %%
c1 = cirq.LineQubit(0)
c2 = cirq.LineQubit(1)
cubits = cirq.LineQubit.range(4)

# %%
cubits[0] == c1
# Out:
# True

# %%
print(cubits)
# Out:
# [cirq.LineQubit(0), cirq.LineQubit(1), cirq.LineQubit(2), cirq.LineQubit(3)]

# %%
circuito = cirq.Circuit()
circuito.append(cirq.H(cubits[0]))
circuito.append(cirq.CNOT(cubits[0], cubits[1]))
#circuito.append(cirq.measure(cubits[0], cubits[1]))

# %%
print(circuito)
# Out:
# 0: ───H───@───
#           │
# 1: ───────X───

# %%
sim = cirq.Simulator()
result = sim.simulate(circuito)

# %%
result
# Out:
# measurements: (no measurements)
#
# qubits: (cirq.LineQubit(0), cirq.LineQubit(1))
# output vector: 0.707|00⟩ + 0.707|11⟩
#
# phase:
# output vector: |⟩

# %%
def kernel_angular(a, b):
    ncubits = min(len(a), len(b))
    circuito = cirq.Circuit()
    cubits = cirq.LineQubit.range(ncubits)
    for i, cubit in enumerate(cubits):
        circuito.append(circ.rx(b[i])(cubit))
    for i, cubit in enumerate(cubits):
        circuito.append(circ.rx(-a[i])(cubit))
    sim = cirq.Simulator()
    result = sim.simulate(circuito)
    return np.abs(result.final_state_vector)**2
