# %% [markdown]
# Camino Hamiltoniano es $\text{NP-completo}$,
# por lo que el código práctico más común es un algoritmo de Búsqueda con Retroceso (Backtracking), que es de complejidad exponencial.

# %%
def es_seguro(v, pos, camino, grafo):
    """
    Verifica si el vértice 'v' se puede agregar al camino.
    Condiciones:
    1. Debe ser adyacente al último vértice del camino (camino[pos-1]).
    2. No debe haber sido incluido ya en el camino.
    """
    # 1. Adyacencia:
    # El grafo está representado como un diccionario donde las claves son los vértices
    # y los valores son conjuntos de sus vecinos.
    if v not in grafo.get(camino[pos-1], set()):
        return False

    # 2. No repetido:
    if v in camino:
        return False

    return True

def resolver_camino_hamiltoniano_util(grafo, camino, pos, N):
    """
    Función recursiva de backtracking para encontrar un camino hamiltoniano.
    """
    # Condición de éxito: Si todos los vértices están en el camino.
    if pos == N:
        # Aquí se encuentra el camino.
        return True

    # Intentar con todos los vértices como la próxima opción.
    for v in grafo.keys():
        # Vértice 'v' debe ser un entero o el tipo usado para las claves del grafo.

        if es_seguro(v, pos, camino, grafo):
            camino[pos] = v

            # Llamada recursiva: si el resto del camino se puede completar.
            if resolver_camino_hamiltoniano_util(grafo, camino, pos + 1, N) == True:
                return True

            # RETROCESO (Backtracking): Si la llamada recursiva falla,
            # deshaz la elección y prueba con otro vértice.
            camino[pos] = -1 # Marcar como no visitado/no usado en esta rama

    return False

def encontrar_camino_hamiltoniano(grafo):
    """
    Función principal que inicializa el proceso de búsqueda.
    """
    N = len(grafo) # Número total de vértices

    # Inicializar el arreglo del camino (donde -1 significa no visitado)
    camino = [-1] * N

    # Probar comenzando el camino desde cada vértice
    for vertice_inicio in grafo.keys():
        camino[0] = vertice_inicio

        print(f"Buscando camino comenzando en {vertice_inicio}...")

        if resolver_camino_hamiltoniano_util(grafo, camino, 1, N) == True:
            print("✅ El grafo TIENE un camino hamiltoniano.")
            print(f"   Camino encontrado: {camino}")
            return True, camino

        # Si falla, resetear el camino para el siguiente intento
        camino = [-1] * N

    print("❌ El grafo NO tiene un camino hamiltoniano.")
    return False, None

# --- EJEMPLO DE USO ---
# Grafo de prueba (Representación con Lista de Adyacencia: Diccionario de Conjuntos)
# Vértices: 0, 1, 2, 3
grafo_ejemplo = {
    0: {1, 3},
    1: {0, 2},
    2: {1, 3},
    3: {0, 2}
}
# Este grafo (Ciclo C4) SÍ tiene un camino hamiltoniano: e.g., 0-1-2-3

# Grafo que es difícil o NO tiene camino/ciclo hamiltoniano (ej. un árbol con un vértice de grado > 2)
# grafo_sin_camino = {
#     0: {1, 2},
#     1: {0, 3},
#     2: {0, 4},
#     3: {1},
#     4: {2}
# }

# Ejecutar el algoritmo
encontrar_camino_hamiltoniano(grafo_ejemplo)

# Salida esperada:
# Buscando camino comenzando en 0...
# ✅ El grafo TIENE un camino hamiltoniano.
#    Camino encontrado: [0, 1, 2, 3]
# Out:
# Buscando camino comenzando en 0...
# ✅ El grafo TIENE un camino hamiltoniano.
#    Camino encontrado: [0, 1, 2, 3]
# (True, [0, 1, 2, 3])

# %% [markdown]
# Notas Clave del CódigoRepresentación del Grafo:
# Se utiliza un diccionario de conjuntos (grafo_ejemplo = {0: {1, 3}, ...}).
# Esto permite una búsqueda rápida de adyacencia (mediante v in grafo.get(...)) y facilita el manejo de grafos no dirigidos.camino: Es una lista que almacena el camino encontrado hasta el momento. La posición pos en la lista indica qué vértice estamos intentando llenar.es_seguro(v, pos, camino, grafo):
# Esta función es crucial. Implementa las reglas de un camino simple:El nuevo vértice ($v$) debe ser adyacente al vértice anterior (camino[pos-1]).El nuevo vértice ($v$) no debe estar ya en el camino.Retroceso (Backtracking): Si la llamada recursiva a resolver_camino_hamiltoniano_util retorna False, la línea camino[pos] = -1 "deshace" la última asignación.
# Esto es el corazón del backtracking, permitiendo que el bucle for pruebe el siguiente vecino disponible.Este código te dará una solución exacta, pero ten en cuenta que su tiempo de ejecución puede ser prohibitivo para grafos con más de unos 20-25 vértices.

# %% [markdown]
# Teorema de Ore: Código de Verificación
# El Teorema de Ore establece:Si $G$ es un grafo simple con $n \ge 3$ vértices y $\mathbf{\text{grado}(u) + \text{grado}(v) \ge n}$ para todo par de vértices no adyacentes $u$ y $v$, entonces $G$ es hamiltoniano (tiene un ciclo hamiltoniano).
# El siguiente código verifica esta condición:

# %%
def verificar_teorema_de_ore(grafo):
    """
    Verifica si el grafo cumple con la condición del Teorema de Ore.

    Argumentos:
    grafo (dict): El grafo representado como una lista de adyacencia
                  (diccionario donde la clave es el vértice y el valor es un conjunto de sus vecinos).

    Retorna:
    bool: True si el grafo cumple la condición de Ore, False en caso contrario.
    """

    n = len(grafo) # Número total de vértices

    # 1. Condición preliminar: El grafo debe tener al menos 3 vértices.
    if n < 3:
        print(f"❌ El grafo tiene menos de 3 vértices ({n}). El Teorema de Ore no aplica directamente.")
        return False

    # Obtener la lista de todos los vértices para iterar
    vertices = list(grafo.keys())

    # Iterar sobre todos los pares de vértices (u, v)
    for i in range(n):
        for j in range(i + 1, n):
            u = vertices[i]
            v = vertices[j]

            # Obtener los grados de los vértices
            grado_u = len(grafo.get(u, set()))
            grado_v = len(grafo.get(v, set()))

            # 2. Verificar si son NO adyacentes
            # u y v son no adyacentes si 'v' no está en la lista de vecinos de 'u'
            if v not in grafo.get(u, set()):

                # 3. Aplicar la condición de Ore: grado(u) + grado(v) < n
                if grado_u + grado_v < n:
                    print(f"❌ Falla la condición de Ore para el par no adyacente ({u}, {v}):")
                    print(f"   Grado({u})={grado_u}, Grado({v})={grado_v}. Suma = {grado_u + grado_v} < n={n}.")
                    return False # El grafo no cumple la condición

    # Si todos los pares no adyacentes cumplen la condición
    print(f"✅ El grafo CUMPLE con la condición del Teorema de Ore (grado(u) + grado(v) >= {n} para todo par no adyacente).")
    print("   Por lo tanto, es garantizado que el grafo tiene un ciclo hamiltoniano.")
    return True

# --- EJEMPLO DE USO ---

# Grafo 1: Grafo completo (K4). n=4. Siempre cumple (es trivial).
# grado(u) = 3 para todos. Suma = 6 >= 4.
grafo_1 = {
    0: {1, 2, 3},
    1: {0, 2, 3},
    2: {0, 1, 3},
    3: {0, 1, 2}
}

# Grafo 2: Ciclo C4. n=4. No tiene pares no adyacentes (u, v) que no cumplen la condición.
# Pares no adyacentes: (0, 2) y (1, 3).
# grado(0)=2, grado(2)=2. Suma = 4 >= 4. CUMPLE.
grafo_2 = {
    0: {1, 3},
    1: {0, 2},
    2: {1, 3},
    3: {0, 2}
}

# Grafo 3: Falla la condición de Ore. (n=5).
# Pares no adyacentes (ej: 0 y 4): grado(0)=2, grado(4)=2. Suma = 4 < n=5. FALLA.
grafo_3_falla = {
    0: {1, 3},
    1: {0, 2},
    2: {1, 3},
    3: {0, 2},
    4: {1, 2}
}

print("--- Verificando Grafo 2 (C4) ---")
verificar_teorema_de_ore(grafo_2)

print("\n--- Verificando Grafo 3 (Falla Ore) ---")
verificar_teorema_de_ore(grafo_3_falla)
# Out:
# --- Verificando Grafo 2 (C4) ---
# ✅ El grafo CUMPLE con la condición del Teorema de Ore (grado(u) + grado(v) >= 4 para todo par no adyacente).
#    Por lo tanto, es garantizado que el grafo tiene un ciclo hamiltoniano.
#
# --- Verificando Grafo 3 (Falla Ore) ---
# ❌ Falla la condición de Ore para el par no adyacente (0, 2):
#    Grado(0)=2, Grado(2)=2. Suma = 4 < n=5.
# False

# %% [markdown]
# Puntos Clave sobre el Teorema de Ore1.
# Condición Suficiente, No NecesariaEl cumplimiento del Teorema de Ore garantiza la existencia de un ciclo hamiltoniano. Sin embargo, si un grafo no cumple la condición de Ore, aún podría ser hamiltoniano.Si CUMPLE la condición de Ore:
# ¡El grafo es hamiltoniano! (Garantizado)Si NO CUMPLE la condición de Ore: Debes usar otro método (como el algoritmo de backtracking que proporcioné antes) para determinar si es hamiltoniano.2.
# Diferencia con el Teorema de DiracEl
# Teorema de Dirac es un caso especial del Teorema de Ore.
# Teorema de Dirac: $\mathbf{\text{grado}(v) \ge n/2}$ para todo vértice $v$. (Esto implica que $\text{grado}(u) + \text{grado}(v) \ge n$, satisfaciendo Ore.)El Teorema de Ore es más general porque solo requiere que la suma de los grados sea $\ge n$ para los pares de vértices no adyacentes.

# %% [markdown]
# **Teorema de Dirac: **
# Código de Verificación
# El Teorema de Dirac establece:Si $G$ es un grafo simple con $n \ge 3$ vértices y si el grado de cada vértice $v$ en $G$ satisface la condición $\mathbf{\text{grado}(v) \ge n/2}$, entonces $G$ es hamiltoniano (tiene un ciclo hamiltoniano).El siguiente código verifica esta condición para un grafo dado:

# %%
def verificar_teorema_de_dirac(grafo):
    """
    Verifica si el grafo cumple con la condición del Teorema de Dirac.

    Argumentos:
    grafo (dict): El grafo representado como una lista de adyacencia
                  (diccionario donde la clave es el vértice y el valor es un conjunto de sus vecinos).

    Retorna:
    bool: True si el grafo cumple la condición de Dirac, False en caso contrario.
    """

    n = len(grafo) # Número total de vértices

    # 1. Condición preliminar: El grafo debe tener al menos 3 vértices.
    if n < 3:
        print(f"❌ El grafo tiene menos de 3 vértices ({n}). El Teorema de Dirac no aplica.")
        return False

    # Calcular el umbral de grado: n / 2
    umbral = n / 2

    # Iterar sobre todos los vértices del grafo
    for vertice, vecinos in grafo.items():
        grado_v = len(vecinos)

        # 2. Aplicar la condición de Dirac: grado(v) < n/2
        if grado_v < umbral:
            print(f"❌ Falla la condición de Dirac para el vértice {vertice}:")
            print(f"   Grado({vertice})={grado_v} < n/2 = {umbral}.")
            return False # El grafo no cumple la condición

    # Si todos los vértices cumplen la condición
    print(f"✅ El grafo CUMPLE con la condición del Teorema de Dirac (grado(v) >= {umbral} para todo v).")
    print("   Por lo tanto, es garantizado que el grafo tiene un ciclo hamiltoniano.")
    return True

# --- EJEMPLO DE USO ---

# Grafo 1: Grafo completo (K5). n=5. Todos los grados son 4. n/2 = 2.5. 4 >= 2.5. CUMPLE.
grafo_1_cumple = {
    0: {1, 2, 3, 4},
    1: {0, 2, 3, 4},
    2: {0, 1, 3, 4},
    3: {0, 1, 2, 4},
    4: {0, 1, 2, 3}
}

# Grafo 2: Grafo ciclo C5. n=5. Todos los grados son 2. n/2 = 2.5. 2 < 2.5. FALLA.
# (Nota: Aunque C5 FALLA Dirac, SÍ es hamiltoniano. Dirac es solo suficiente).
grafo_2_falla = {
    0: {1, 4},
    1: {0, 2},
    2: {1, 3},
    3: {2, 4},
    4: {3, 0}
}

print("--- Verificando Grafo 1 (K5) ---")
verificar_teorema_de_dirac(grafo_1_cumple)

print("\n--- Verificando Grafo 2 (C5) ---")
verificar_teorema_de_dirac(grafo_2_falla)
# Out:
# --- Verificando Grafo 1 (K5) ---
# ✅ El grafo CUMPLE con la condición del Teorema de Dirac (grado(v) >= 2.5 para todo v).
#    Por lo tanto, es garantizado que el grafo tiene un ciclo hamiltoniano.
#
# --- Verificando Grafo 2 (C5) ---
# ❌ Falla la condición de Dirac para el vértice 0:
#    Grado(0)=2 < n/2 = 2.5.
# False

# %% [markdown]
# **Relación con el Camino Hamiltoniano**
# Es importante recordar que el Teorema de Dirac solo garantiza la existencia de un ciclo hamiltoniano.
# Si un grafo tiene un ciclo hamiltoniano, automáticamente tiene un camino hamiltoniano.
#
# **Si el grafo cumple Dirac, sabes que existe un ciclo**, pero el código no te dice cuál es ese ciclo. Para encontrar el ciclo o camino, aún necesitarías usar un algoritmo de búsqueda (como el backtracking que te proporcioné previamente).

# %% [markdown]
# **Código Python para Encontrar un Ciclo Hamiltoniano (Backtracking)**
# La principal diferencia con el código del camino es la condición de éxito y la condición de seguridad final:Condición de Éxito:
# El camino debe incluir todos los $N$ vértices.Condición de Ciclo: El último vértice añadido (después de visitar el vértice $N$) debe ser adyacente al vértice inicial del camino (el primer vértice).

# %% [markdown]
# **Resumen de la Modificación Clave**
# La única modificación significativa para pasar de buscar un Camino a buscar un Ciclo está en la función recursiva resolver_ciclo_hamiltoniano_util:

# %% [markdown]
# Esta verificación asegura que la ruta completa a través de todos los vértices ($N$) pueda regresar al punto de partida original.

# %% [markdown]
# **🐍 Código Completo y Correcto para Ciclo Hamiltoniano**

# %%
def es_seguro(v, pos, camino, grafo):
    """
    Verifica si el vértice 'v' es una opción segura para la posición 'pos' del camino.

    Condiciones:
    1. 'v' debe ser adyacente al vértice anterior (camino[pos-1]).
    2. 'v' no debe haber sido visitado previamente.
    """
    # Condición 1: Adyacencia
    # El camino[pos-1] es el último vértice añadido.
    if v not in grafo.get(camino[pos-1], set()):
        return False

    # Condición 2: No repetido
    # Revisamos solo las posiciones ya ocupadas (de 0 hasta pos-1)
    if v in camino[:pos]:
        return False

    return True

def resolver_ciclo_hamiltoniano_util(grafo, camino, pos, N, vertice_inicio):
    """
    Función recursiva de backtracking para encontrar un ciclo hamiltoniano.

    Argumentos:
    grafo (dict): Lista de adyacencia.
    camino (list): Arreglo que almacena la ruta actual.
    pos (int): La posición del vértice que se está intentando llenar.
    N (int): El número total de vértices.
    vertice_inicio (int/str): El vértice donde debe iniciar y terminar el ciclo.
    """

    # Condición de éxito: Todos los vértices han sido visitados (camino completo)
    if pos == N:
        # AHORA verificamos la condición de CICLO:
        # El último vértice (camino[N-1]) debe ser adyacente al vertice_inicio.
        if vertice_inicio in grafo.get(camino[N-1], set()):
            return True # ¡Ciclo encontrado!
        else:
            return False # Es un camino, pero no cierra el ciclo

    # Intentar con cada vértice como el próximo paso
    for v in grafo.keys():

        if es_seguro(v, pos, camino, grafo):
            camino[pos] = v

            # Llamada recursiva: si el resto del camino se puede completar
            if resolver_ciclo_hamiltoniano_util(grafo, camino, pos + 1, N, vertice_inicio) == True:
                return True

            # 🔄 RETROCESO (Backtracking): Deshacer la elección si la rama falló
            camino[pos] = -1 # Marcar como no usado en esta rama

    return False

def encontrar_ciclo_hamiltoniano(grafo):
    """
    Función principal que inicia la búsqueda del ciclo hamiltoniano.
    """
    N = len(grafo)

    if N < 3:
        print("❌ El grafo debe tener al menos 3 vértices para tener un ciclo.")
        return False, None

    # Elegimos el primer vértice disponible como punto de inicio y fin.
    # Si existe un ciclo, existirá independientemente del punto de partida.
    vertices = list(grafo.keys())
    vertice_inicio = vertices[0]

    # Inicializar el arreglo del camino. Usamos None o -1 para indicar que no ha sido visitado.
    camino = [-1] * N
    camino[0] = vertice_inicio

    print(f"Buscando ciclo hamiltoniano (N={N}) comenzando y terminando en {vertice_inicio}...")

    # Iniciar la búsqueda recursiva desde la posición 1
    if resolver_ciclo_hamiltoniano_util(grafo, camino, 1, N, vertice_inicio) == True:
        # Añadir el vértice inicial al final para mostrar el ciclo completo
        ciclo_encontrado = camino + [vertice_inicio]
        print("✅ Éxito: El grafo TIENE un ciclo hamiltoniano.")
        print(f"   Ciclo encontrado: {ciclo_encontrado}")
        return True, ciclo_encontrado
    else:
        print("❌ Fallo: El grafo NO tiene un ciclo hamiltoniano (o no se encontró uno desde el inicio).")
        return False, None

# --- EJEMPLO DE USO ---

# Grafo Hamiltoniano (Ciclo C4): Tiene ciclo 0-1-2-3-0
grafo_ejemplo_ciclo = {
    0: {1, 3},
    1: {0, 2},
    2: {1, 3},
    3: {0, 2}
}

# Grafo que NO es Hamiltoniano (ej. un árbol con un vértice central):
# Intentar 0-1-3. No puede volver a 0.
grafo_ejemplo_no_ciclo = {
    0: {1, 2},
    1: {0, 3},
    2: {0, 4},
    3: {1},
    4: {2}
}

print("\n--- TEST 1: Grafo con Ciclo Hamiltoniano (C4) ---")
encontrar_ciclo_hamiltoniano(grafo_ejemplo_ciclo)

print("\n--- TEST 2: Grafo sin Ciclo Hamiltoniano ---")
encontrar_ciclo_hamiltoniano(grafo_ejemplo_no_ciclo)
# Out:
# --- TEST 1: Grafo con Ciclo Hamiltoniano (C4) ---
# Buscando ciclo hamiltoniano (N=4) comenzando y terminando en 0...
# ✅ Éxito: El grafo TIENE un ciclo hamiltoniano.
#    Ciclo encontrado: [0, 1, 2, 3, 0]
#
# --- TEST 2: Grafo sin Ciclo Hamiltoniano ---
# Buscando ciclo hamiltoniano (N=5) comenzando y terminando en 0...
# ❌ Fallo: El grafo NO tiene un ciclo hamiltoniano (o no se encontró uno desde el inicio).
# (False, None)

# %% [markdown]
# **Cómo Funciona el Backtracking**
# *El algoritmo de Backtracking resuelve este problema $\text{NP-completo}$ mediante una búsqueda exhaustiva inteligente:Construcción Incremental: *
# El algoritmo construye el camino paso a paso, llenando el arreglo camino de la posición 1 hasta $N$.
# Verificación de Seguridad (es_seguro): Antes de colocar un vértice, verifica dos condiciones cruciales: adyacencia y que no se haya visitado antes.
# Retroceso (Backtracking): Si la función recursiva no puede avanzar (todos los caminos desde un punto fallan), retorna False y el código deshace la última elección (camino[pos] = -1), permitiendo que el bucle for pruebe con el siguiente vecino.Cierre de Ciclo:
# **La condición final de éxito (if pos == N) verifica que el último vértice visitado pueda conectarse de vuelta al punto de partida (vertice_inicio), cerrando así el ciclo.Este método garantiza la correctitud de la solución, pero su complejidad es exponencial ($O(N!)$ en el peor caso), haciéndolo lento para grafos grandes.**
